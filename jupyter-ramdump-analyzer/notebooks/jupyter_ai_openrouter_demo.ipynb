# %% [markdown]
# # Jupyter AI + OpenRouter Demo
#
# This notebook shows two paths:
# - reproducible notebook magic via `%%ai`
# - JupyterLab chat UI as a companion workflow

# %%
# %load_ext jupyter_ai

# %% [markdown]
# Before running the next cell, configure OpenRouter in Jupyter AI or set the OpenAI-compatible base URL and key in your environment.

# %%
# %%ai openai-chat:nvidia/nemotron-3-super-120b-a12b:free
# You are helping analyze a Linux vmcore and kernel log. Summarize the key steps needed to validate a panic root cause from vmcore, vmlinux, and module symbols.

# %% [markdown]
# Use the JupyterLab chat sidebar for iterative prompt refinement and file-aware exploration.
